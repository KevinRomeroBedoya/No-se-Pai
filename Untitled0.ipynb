# %% [markdown]
# <a href="https://colab.research.google.com/github/KevinRomeroBedoya/No-se-Pai/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# importar librerias necesarias

import numpy as np
import matplotlib.pyplot as plt
import cv2
from google.colab.patches import cv2_imshow

# graficar imagenes estaticas en el notebook

# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
selfie = cv2.imread('/content/drive/My Drive/PDI/CoronaVirus.jpg', cv2.IMREAD_UNCHANGED)
cv2_imshow(selfie)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=800x523 at 0x7FBD39B81828>
# -1

# %%
# !pwd
# !ls
# %cd../
# %cd /content/drive/My Drive/PDI/
# !pwd
# Out:
# /content/drive/My Drive/PDI
# /content/drive/My Drive/PDI

# %%
selfie = cv2.imread('CoronaVirus.jpg', cv2.IMREAD_UNCHANGED)
selfie = cv2.resize(selfie,(int(800), int(523)))
cv2_imshow(selfie)
# Out:
# <PIL.Image.Image image mode=RGB size=800x523 at 0x7FBD37ED40F0>

# %%
import os
path='/content/drive/My Drive/PDI/'
os.chdir(path)
# !pwd
selfie = cv2.imread('CoronaVirus.jpg', cv2.IMREAD_UNCHANGED)
selfie = cv2.resize(selfie,(int(800), int(523)))
cv2_imshow(selfie)
# Out:
# /content/drive/My Drive/PDI
# <PIL.Image.Image image mode=RGB size=800x523 at 0x7FBD37ED4588>

# %%
# leer una imagen
# principle of least astonishment
selfie = cv2.imread('CoronaVirus.jpg', cv2.IMREAD_COLOR)
#
plt.figure(figsize=(7,7))
plt.imshow(selfie)
plt.show()
